# %%
# !pip install py3Dmol
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from IPython import display
import ipywidgets as widgets
import numpy as np
from google.colab import files

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Step 1: Ask for the protein sequence
uplouded_files = files.upload()

# pdb_file = input("Enter the path to the PDB file: ")

embeding_options = ['Option 1', 'Option 2', 'Option 3','other...']

# Step 2: Ask for the embedding type
embedding_type = input("Enter the embedding type the options are:"+' '.join(embeding_options))

# if choose other
if embedding_type not in embeding_options:
    # Step 2: Ask for the matrix file
    matrix_file = input("Enter the path to the matrix file: ")
    # Load the data from the text file into a NumPy array
    data_array = np.loadtxt('/content/drive/My Drive/Colab Notebooks/' + matrix_file, dtype=int)

    # check matrix input
    num_rows, num_columns = data_array.shape
    if num_rows != len(protein_sequence):
        print("The numbers of rows must be equal to the len of the sequence, try again.")


# pass to sapir the pdb file and the embeding name or matrix
predicted_pdb = ?
# Get the PDB file and display the 3D protein structure

# Create a viewer object
view = py3Dmol.view(width=800, height=600)

# Load the PDB file into the viewer
view.addModel(open('/content/drive/My Drive/Colab Notebooks/'+predicted_pdb, 'r').read(), 'pdb')

# Set the style for the protein structure
view.setStyle({'cartoon': {'color': 'spectrum'}})

# Set the background color
view.setBackgroundColor('white')

# Center and zoom the view
view.zoomTo()

# Show the viewer
view.show()














# def other_embeding():
#     # Step 3: Ask for the matrix file
#     matrix_file = input("Enter the path to the matrix file: ")
#     # Read and save the matrix
#     # Load the data from the text file into a NumPy array
#     data_array = np.loadtxt(matrix_file, dtype=int)

#     print(data_array)

#     # with open(matrix_file, 'r') as f:
#     #     matrix = f.read()


# Step 2: Ask for the embedding type
# embeding_options = ['Option 1', 'Option 2', 'Option 3','other']
# dropdown = widgets.Dropdown(options = embeding_options,
#                             # value='Option 1',
#                             description='Select an option:')
# display.display(dropdown)


# button = widgets.Button(description="predict protein structure")

# def on_button_click(b):
#     # To access the selected value:
#     selected_option = dropdown.value
#     print("Selected option:", selected_option)
#     if selected_option == 'other':
#         # other_embeding()
#         matrix_file = input("Enter the path to the matrix file: ")
#         # Read and save the matrix
#         # Load the data from the text file into a NumPy array
#         # data_array = np.loadtxt(matrix_file, dtype=int)

#         # print(data_array)


# display.display(button)

# button.on_click(on_button_click)
# Out:
#      <input type="file" id="files-4fd05f9e-2068-4180-9ac4-f8c0bb640966" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4fd05f9e-2068-4180-9ac4-f8c0bb640966">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
